# %% [markdown]
# ## Start Spark Session

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .master("spark://iceberg-sandbox-spark-master:7077")
    .appName("iceberg-sandbox")
    .config("spark.driver.host", "iceberg-sandbox-jupyter")
    .config("spark.driver.bindAddress", "0.0.0.0")
    .config("spark.driver.port", "7078")
    .config("spark.blockManager.port", "7079")
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions")
    .config("spark.sql.catalog.iceberg_jdbc", "org.apache.iceberg.spark.SparkCatalog")
    .config("spark.sql.catalog.iceberg_jdbc.catalog-impl", "org.apache.iceberg.jdbc.JdbcCatalog")
    .config("spark.sql.catalog.iceberg_jdbc.uri", "jdbc:postgresql://iceberg-sandbox-postgres:5432/iceberg-jdbc-catalog")
    .config("spark.sql.catalog.iceberg_jdbc.jdbc.user", "iceberg")
    .config("spark.sql.catalog.iceberg_jdbc.jdbc.password", "iceberg")
    .config("spark.sql.catalog.iceberg_jdbc.jdbc.driver", "org.postgresql.Driver")
    .config("spark.sql.catalog.iceberg_jdbc.warehouse", "s3a://iceberg/warehouse")
    .config("spark.hadoop.fs.s3a.endpoint", "http://iceberg-sandbox-minio:9000")
    .config("spark.hadoop.fs.s3a.access.key", "minioadmin")
    .config("spark.hadoop.fs.s3a.secret.key", "minioadmin")
    .config("spark.hadoop.fs.s3a.path.style.access", "true")
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
    .config("spark.executor.cores", "1")
    .config("spark.executor.memory", "1g")
    .config("spark.cores.max", "1")
    .config("spark.ui.showConsoleProgress", "true")
    .getOrCreate()
)

# %% [markdown]
# ## Iceberg Features: 1. Time Travel

# %% [markdown]
# ### Check Snapshots

# %%
spark.sql("""
SELECT * 
FROM iceberg_jdbc.ecommerce.orders.snapshots
""").show(truncate=False)
# Out:
# +-----------------------+-------------------+---------+---------+----------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |committed_at           |snapshot_id        |parent_id|operation|manifest_list                                                                                                         |summary                                                                                                                                                                                                                                                                                                           |
# +-----------------------+-------------------+---------+---------+----------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2026-02-23 04:38:24.072|6223667570380203935|NULL     |append   |s3a://iceberg/warehouse/ecommerce/orders/metadata/snap-6223667570380203935-1-839bfd6a-57ce-4921-a685-84683b1b7302.avro|{spark.app.id -> app-20260223043748-0001, added-data-files -> 2, added-records -> 89316, added-files-size -> 3494546, changed-partition-count -> 1, total-records -> 89316, total-files-size -> 3494546, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-02-23 04:40:24.048|546889620057850498 |NULL     |append   |s3a://iceberg/warehouse/ecommerce/orders/metadata/snap-546889620057850498-1-7073babf-24fe-4259-b515-b4ac7ebdf7bd.avro |{spark.app.id -> app-20260223043932-0002, added-data-files -> 2, added-records -> 89316, added-files-size -> 3494546, changed-partition-count -> 1, total-records -> 89316, total-files-size -> 3494546, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# |2026-02-23 06:58:02.876|7428214545948977217|NULL     |append   |s3a://iceberg/warehouse/ecommerce/orders/metadata/snap-7428214545948977217-1-a3acc968-1d2c-480f-aafe-2a5bb1c5ad60.avro|{spark.app.id -> app-20260223065739-0004, added-data-files -> 2, added-records -> 89316, added-files-size -> 3494546, changed-partition-count -> 1, total-records -> 89316, total-files-size -> 3494546, total-data-files -> 2, total-delete-files -> 0, total-position-deletes -> 0, total-equality-deletes -> 0}|
# +-----------------------+-------------------+---------+---------+----------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ### Delete data

# %%
spark.sql("""DELETE FROM iceberg_jdbc.ecommerce.orders
WHERE order_status = 'canceled';""")
# Out:
# DataFrame[]

# %% [markdown]
# ### Check Available Snapshots

# %%
spark.sql("""SELECT snapshot_id, committed_at, operation
FROM iceberg_jdbc.ecommerce.orders.snapshots
ORDER BY committed_at desc;
""").show(truncate=False)
# Out:
# +-------------------+-----------------------+---------+
# |snapshot_id        |committed_at           |operation|
# +-------------------+-----------------------+---------+
# |3487823717667428865|2026-02-23 06:59:37.708|overwrite|
# |7428214545948977217|2026-02-23 06:58:02.876|append   |
# |546889620057850498 |2026-02-23 04:40:24.048|append   |
# |6223667570380203935|2026-02-23 04:38:24.072|append   |
# +-------------------+-----------------------+---------+

# %%
df_snapshot = spark.sql("""
SELECT snapshot_id
FROM (
    SELECT 
        snapshot_id,
        committed_at,
        operation,
        ROW_NUMBER() OVER (ORDER BY committed_at DESC) as rn
    FROM iceberg_jdbc.ecommerce.orders.snapshots
) t
WHERE rn = 2
""")

# Extract value into Python variable
snapshot_id = df_snapshot.collect()[0]["snapshot_id"]

print(snapshot_id)
# Out:
# 7428214545948977217

# %% [markdown]
# ### Check the snapshot data

# %%
spark.sql(f"""SELECT * FROM iceberg_jdbc.ecommerce.orders VERSION AS OF {snapshot_id}""").show()
# Out:
# +------------+------------+------------+------------------------+-------------------+-------------------------+-----------------------------+
# |    order_id| customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_timestamp|order_estimated_delivery_date|
# +------------+------------+------------+------------------------+-------------------+-------------------------+-----------------------------+
# |Axfy13Hk4PIk|hCT0x9JiGXBQ|   delivered|     2017-10-22 18:57:54|2017-10-22 19:14:13|      2017-10-26 22:19:52|                   2017-11-09|
# |v6px92oS8cLG|PxA7fv9spyhx|   delivered|     2018-06-20 21:40:31|2018-06-20 22:20:20|      2018-07-03 22:51:22|                   2018-07-24|
# |Ulpf9skrhjfm|g3nXeJkGI0Qw|   delivered|     2018-02-16 16:19:31|2018-02-17 16:15:35|      2018-02-27 01:29:50|                   2018-03-08|
# |bwJVWupf2keN|EOEsCQ6QlpIg|   delivered|     2018-08-18 18:04:29|2018-08-18 18:15:16|      2018-08-27 20:03:51|                   2018-09-19|
# |Dd0QnrMk9Cj5|mVz5LO2Vd6cL|   delivered|     2017-12-22 16:44:04|2017-12-22 17:31:31|      2018-01-05 19:22:49|                   2018-01-18|
# |VjTVGzqe8U6R|UkqnhxmX7YMP|   delivered|     2017-09-01 14:38:16|2017-09-01 14:50:24|      2017-09-15 18:57:50|                   2017-09-26|
# |xNba906m4TM1|85jiDiGSfhTu|   delivered|     2018-04-23 21:03:00|2018-04-24 18:18:18|      2018-04-25 20:14:38|                   2018-05-04|
# |VEDSMTavbQwk|gDdkaN8b9s1g|   delivered|     2018-02-23 14:49:39|2018-02-23 15:16:13|      2018-04-02 14:12:50|                   2018-03-15|
# |DzNM8wrcMGFH|9Csx6oXlpLl1|   delivered|     2017-11-24 19:12:37|2017-11-25 04:54:03|      2017-12-11 13:09:32|                   2017-12-14|
# |NpJz7zF9U1ae|gZTPKLPRnreg|   delivered|     2017-11-30 11:48:21|2017-11-30 13:31:19|      2017-12-14 16:38:47|                   2018-01-03|
# |mHyhzcUeLGj2|TDEBQrhIwApB|   delivered|     2018-04-02 22:39:59|2018-04-03 22:35:18|      2018-04-13 18:12:30|                   2018-04-23|
# |StM5K4TLyrt5|1k71TCYNFCzj|   delivered|     2018-05-30 09:25:25|2018-05-30 09:35:16|      2018-06-21 18:22:15|                   2018-07-05|
# |Q97dFuo1kaq9|IfWKDQHkjLDd|   delivered|     2018-04-10 00:17:56|2018-04-10 00:35:11|      2018-04-20 18:03:58|                   2018-05-04|
# |07j6mlMhSVtx|kZ0rkJCJ6N5y|   delivered|     2018-05-02 22:52:10|2018-05-03 00:13:21|      2018-05-09 23:48:32|                   2018-05-18|
# |kxa1InBj9gwP|zsCKIdqYLV01|   delivered|     2017-04-24 20:06:41|2017-04-24 20:22:24|      2017-05-05 10:22:27|                   2017-05-25|
# |P5R6jr1qZdh4|FrEvnEiMKGpr|    canceled|     2017-07-24 11:38:43|2017-07-24 11:50:18|                     NULL|                   2017-08-07|
# |HqV5f8K2UYoA|3zvaY9gUH9bO|   delivered|     2018-06-15 15:44:21|2018-06-15 16:00:22|      2018-06-25 22:27:56|                   2018-07-11|
# |j5rwgECNf14O|bUornDCZmRD4|   delivered|     2018-03-15 11:13:23|2018-03-15 11:29:14|      2018-04-09 18:54:36|                   2018-04-03|
# |43It0OEHVyJe|qEVfsXFU3er9|   delivered|     2017-03-05 16:10:01|2017-03-05 16:25:11|      2017-04-18 15:28:21|                   2017-04-06|
# |ddXx4T93MeaI|mPg90mQwmDOP|   delivered|     2017-10-03 12:58:11|2017-10-03 13:07:28|      2017-10-09 14:06:32|                   2017-10-30|
# +------------+------------+------------+------------------------+-------------------+-------------------------+-----------------------------+
# only showing top 20 rows

# %% [markdown]
# ### Rollback the table

# %%
spark.sql(f"""
CALL iceberg_jdbc.system.rollback_to_snapshot(
  table => 'ecommerce.orders',
  snapshot_id => {snapshot_id}
)
""")
# Out:
# DataFrame[previous_snapshot_id: bigint, current_snapshot_id: bigint]

# %% [markdown]
# ### Check the table Again

# %%
spark.sql("""
SELECT * from iceberg_jdbc.ecommerce.orders where order_status = 'canceled'
""").show(truncate=False)
# Out:
# +------------+------------+------------+------------------------+-------------------+-------------------------+-----------------------------+
# |order_id    |customer_id |order_status|order_purchase_timestamp|order_approved_at  |order_delivered_timestamp|order_estimated_delivery_date|
# +------------+------------+------------+------------------------+-------------------+-------------------------+-----------------------------+
# |P5R6jr1qZdh4|FrEvnEiMKGpr|canceled    |2017-07-24 11:38:43     |2017-07-24 11:50:18|NULL                     |2017-08-07                   |
# |2HQ26ShSPhCA|uvuFFZDOAlU7|canceled    |2017-07-29 12:56:17     |2017-07-29 13:05:18|NULL                     |2017-08-18                   |
# |1By8LOosrvF2|grsbZ5L1H5ty|canceled    |2017-11-06 15:47:20     |2017-11-07 07:30:29|NULL                     |2017-11-28                   |
# |70G4cTVwm38h|WnCydkx96ul3|canceled    |2018-07-04 16:05:56     |2018-07-06 02:55:16|NULL                     |2018-08-22                   |
# |aDxB5SgA7C4q|ejNZQ7X7x2T3|canceled    |2018-02-05 16:30:33     |2018-02-05 16:52:11|NULL                     |2018-03-12                   |
# |eOsGCznIAUFY|8fvg91ZFtCrC|canceled    |2018-05-15 13:17:14     |2018-05-17 03:34:46|NULL                     |2018-06-01                   |
# |ybF89OMhc7TN|q4lNbZvvFSVZ|canceled    |2018-01-21 12:44:16     |2018-01-22 13:49:10|NULL                     |2018-02-19                   |
# |phwkJVrvBPEl|nvWyUkKdosEh|canceled    |2018-02-02 16:06:44     |2018-02-06 04:32:39|NULL                     |2018-03-08                   |
# |WQyxOwsaeGJJ|r5GltRR4NMno|canceled    |2017-07-09 18:18:03     |2017-07-11 03:55:28|NULL                     |2017-07-28                   |
# |V96qMrzxoTeK|8eNsjceRARoS|canceled    |2017-05-12 10:28:30     |2017-05-12 10:42:45|NULL                     |2017-06-05                   |
# |7v81kkUsKYxS|TyTBU8JSnhye|canceled    |2018-08-07 14:27:32     |2018-08-07 14:44:55|NULL                     |2018-08-21                   |
# |bKBmRknvTHRa|8QAvgiTvhZWg|canceled    |2018-07-21 17:59:37     |2018-07-21 18:10:10|NULL                     |2018-08-06                   |
# |ArSJrzgk426f|hDyxglCVsq1u|canceled    |2017-04-10 00:45:56     |2017-04-10 01:03:29|NULL                     |2017-05-04                   |
# |gFtUvcm6ag1h|XdYHdXbNOMIr|canceled    |2017-05-25 13:07:50     |2017-05-25 13:22:31|NULL                     |2017-06-19                   |
# |aSQAU7IR0n3C|oMkwC8jwHi8O|canceled    |2018-02-06 13:44:50     |2018-02-06 15:55:40|NULL                     |2018-03-12                   |
# |sGBTgC6jLo1m|6KXHn4cHUSgq|canceled    |2017-02-03 11:31:48     |2017-02-03 11:45:09|NULL                     |2017-03-28                   |
# |410xjGccgK0R|KRwlyuCul3mn|canceled    |2018-04-06 22:13:21     |2018-04-06 22:29:11|NULL                     |2018-04-25                   |
# |VYcOMlMWmqCI|CJKkS0YPfO6B|canceled    |2017-10-20 16:14:06     |2017-10-20 16:32:34|NULL                     |2017-11-01                   |
# |L93g0SK6OPfq|9IULdi1TNX86|canceled    |2017-11-15 07:45:44     |2017-11-15 07:55:26|NULL                     |2017-11-30                   |
# |R5tdLiLxdkwT|xqpAPWusbPeo|canceled    |2018-02-02 17:42:31     |2018-02-02 17:52:12|NULL                     |2018-03-09                   |
# +------------+------------+------------+------------------------+-------------------+-------------------------+-----------------------------+
# only showing top 20 rows

# %% [markdown]
# ### Check Iceberg Time Travel Retention (Currently Unlimited / Default)

# %%
spark.sql("""
SHOW TBLPROPERTIES iceberg_jdbc.ecommerce.orders;
""").show(truncate=False)
# Out:
# +-------------------------------+-------------------+
# |key                            |value              |
# +-------------------------------+-------------------+
# |current-snapshot-id            |7428214545948977217|
# |format                         |iceberg/parquet    |
# |format-version                 |2                  |
# |write.parquet.compression-codec|zstd               |
# +-------------------------------+-------------------+

# %% [markdown]
# ### Set the Snapshots Time Travel Retention
#
# - Keep snapshots up to 7 days old
# - Always keep at least 5 snapshots
# - Even if older than 7 days

# %%
spark.sql("""
ALTER TABLE iceberg_jdbc.ecommerce.orders
SET TBLPROPERTIES (
  'history.expire.max-snapshot-age-ms'='604800000',
  'history.expire.min-snapshots-to-keep'='5'
);
""")
# Out:
# DataFrame[]

# %% [markdown]
# ### Check Iceberg Time Travel Retention (Altered)

# %%
spark.sql("""
SHOW TBLPROPERTIES iceberg_jdbc.ecommerce.orders;
""").show(truncate=False)
# Out:
# +------------------------------------+-------------------+
# |key                                 |value              |
# +------------------------------------+-------------------+
# |current-snapshot-id                 |7428214545948977217|
# |format                              |iceberg/parquet    |
# |format-version                      |2                  |
# |history.expire.max-snapshot-age-ms  |604800000          |
# |history.expire.min-snapshots-to-keep|5                  |
# |write.parquet.compression-codec     |zstd               |
# +------------------------------------+-------------------+

# %% [markdown]
# ### Enforce / Apply the Retention Time
#
# Iceberg doesnt automatically delete expired snapshot, it should be run manually or automatically via scheduler. and it cant execute the query one for all.

# %%
spark.sql("""
CALL iceberg_jdbc.system.expire_snapshots(
  table => 'ecommerce.orders'
)
""").show(truncate=False)
# Out:
# +------------------------+-----------------------------------+-----------------------------------+----------------------------+----------------------------+------------------------------+
# |deleted_data_files_count|deleted_position_delete_files_count|deleted_equality_delete_files_count|deleted_manifest_files_count|deleted_manifest_lists_count|deleted_statistics_files_count|
# +------------------------+-----------------------------------+-----------------------------------+----------------------------+----------------------------+------------------------------+
# |0                       |0                                  |0                                  |0                           |0                           |0                             |
# +------------------------+-----------------------------------+-----------------------------------+----------------------------+----------------------------+------------------------------+

# %% [markdown]
# ### Enforece / Apply the Snapshot Retention For All Iceberg Table

# %%
schemas = spark.sql("SHOW DATABASES IN iceberg_jdbc").collect()

for s in schemas:
    schema = s.namespace

    tables = spark.sql(f"SHOW TABLES IN iceberg_jdbc.{schema}").collect()

    for t in tables:
        table_name = f"{schema}.{t.tableName}"

        spark.sql(f"""
            CALL iceberg_jdbc.system.expire_snapshots(
              table => '{table_name}'
            )
        """)

# %% [markdown]
# ## Iceberg Features: 2. Merge

# %% [markdown]
# ### Create Temp Data

# %%
spark.sql("""
CREATE OR REPLACE TEMP VIEW orders_stage AS
SELECT
  'P5R6jr1qZdh4' AS order_id,
  'cust_001' AS customer_id,
  'delivered' AS order_status,
  current_timestamp() AS order_purchase_timestamp,
  current_timestamp() AS order_approved_at,
  current_timestamp() AS order_delivered_timestamp,
  current_date() AS order_estimated_delivery_date

UNION ALL

SELECT
  'NEW_ORDER_123' AS order_id,
  'cust_999' AS customer_id,
  'processing' AS order_status,
  current_timestamp() AS order_purchase_timestamp,
  current_timestamp() AS order_approved_at,
  NULL AS order_delivered_timestamp,
  current_date() AS order_estimated_delivery_date
""")

spark.sql("SELECT * FROM orders_stage").show(truncate=False)
# Out:
# +-------------+-----------+------------+--------------------------+--------------------------+--------------------------+-----------------------------+
# |order_id     |customer_id|order_status|order_purchase_timestamp  |order_approved_at         |order_delivered_timestamp |order_estimated_delivery_date|
# +-------------+-----------+------------+--------------------------+--------------------------+--------------------------+-----------------------------+
# |P5R6jr1qZdh4 |cust_001   |delivered   |2026-02-23 07:05:23.164715|2026-02-23 07:05:23.164715|2026-02-23 07:05:23.164715|2026-02-23                   |
# |NEW_ORDER_123|cust_999   |processing  |2026-02-23 07:05:23.164715|2026-02-23 07:05:23.164715|NULL                      |2026-02-23                   |
# +-------------+-----------+------------+--------------------------+--------------------------+--------------------------+-----------------------------+

# %% [markdown]
# ### UPSERT Using MERGE

# %%
spark.sql("""
MERGE INTO iceberg_jdbc.ecommerce.orders t
USING orders_stage s
ON t.order_id = s.order_id

WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *
""")
# Out:
# DataFrame[]

# %% [markdown]
# ### Check Upserted Data

# %%
spark.sql("SELECT * FROM iceberg_jdbc.ecommerce.orders where order_id in ('P5R6jr1qZdh4', 'NEW_ORDER_123')").show(truncate=False)
# Out:
# +-------------+-----------+------------+--------------------------+--------------------------+--------------------------+-----------------------------+
# |order_id     |customer_id|order_status|order_purchase_timestamp  |order_approved_at         |order_delivered_timestamp |order_estimated_delivery_date|
# +-------------+-----------+------------+--------------------------+--------------------------+--------------------------+-----------------------------+
# |NEW_ORDER_123|cust_999   |processing  |2026-02-23 07:05:29.541247|2026-02-23 07:05:29.541247|NULL                      |2026-02-23                   |
# |P5R6jr1qZdh4 |cust_001   |delivered   |2026-02-23 07:05:29.541247|2026-02-23 07:05:29.541247|2026-02-23 07:05:29.541247|2026-02-23                   |
# +-------------+-----------+------------+--------------------------+--------------------------+--------------------------+-----------------------------+

# %% [markdown]
# ### Check the Latest Snapshot

# %%
spark.sql("""
SELECT snapshot_id, committed_at, operation
FROM iceberg_jdbc.ecommerce.orders.snapshots
ORDER BY committed_at DESC;
""").show(truncate=False)
# Out:
# +-------------------+-----------------------+---------+
# |snapshot_id        |committed_at           |operation|
# +-------------------+-----------------------+---------+
# |6977739499014344028|2026-02-23 07:05:32.408|overwrite|
# |3487823717667428865|2026-02-23 06:59:37.708|overwrite|
# |7428214545948977217|2026-02-23 06:58:02.876|append   |
# |546889620057850498 |2026-02-23 04:40:24.048|append   |
# |6223667570380203935|2026-02-23 04:38:24.072|append   |
# +-------------------+-----------------------+---------+

# %%
df_snapshot = spark.sql("""
SELECT snapshot_id
FROM (
    SELECT 
        snapshot_id,
        committed_at,
        operation,
        ROW_NUMBER() OVER (ORDER BY committed_at DESC) as rn
    FROM iceberg_jdbc.ecommerce.orders.snapshots
) t
WHERE rn = 3
""")

# Extract value into Python variable
snapshot_id = df_snapshot.collect()[0]["snapshot_id"]

print(snapshot_id)
# Out:
# 7428214545948977217

# %% [markdown]
# ### Rollback the table snapshot

# %%
spark.sql(f"""
CALL iceberg_jdbc.system.rollback_to_snapshot(
  table => 'ecommerce.orders',
  snapshot_id => {snapshot_id}
)
""").show(truncate=False)
# Out:
# +--------------------+-------------------+
# |previous_snapshot_id|current_snapshot_id|
# +--------------------+-------------------+
# |6977739499014344028 |7428214545948977217|
# +--------------------+-------------------+

# %% [markdown]
# ## Iceberg Features: 3. Schema Evolution

# %%
##spark.stop()
